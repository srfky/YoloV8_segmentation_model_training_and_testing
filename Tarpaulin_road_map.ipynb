# %%
# Install the ultralytics package using pip
# !pip install ultralytics

# %%
from ultralytics import YOLO
from matplotlib import pyplot as plt
from PIL import Image

# %%
model = YOLO('yolov8n-seg.yaml')  # build a new model from YAML
model = YOLO('yolov8n-seg.pt')

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lT5dh03nVQTwMwa0lXtS")
project = rf.workspace("sevde-aslantrkiyeli").project("teknofest-quantum-2025")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
project = "/content/Teknofest-Quantum-2025-1"
#Define subdirectory for this specific training
name = "200_epochs-"

# %%
results = model.train(data='/content/Teknofest-Quantum-2025-1/data.yaml',
                      project=project,
                      name=name,
                      epochs=200,
                      patience=0,
                      batch=4,
                      imgsz=640)
# Out:
# Ultralytics 8.3.158 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
my_new_model = YOLO('/content/Teknofest-Quantum-2025-1/200_epochs-/weights/best.pt')

# %%
new_image = '/content/Teknofest-Quantum-2025-1/test/images/15_png.rf.e30c52c9fa7ca06defb680486433f313.jpg'
new_results = my_new_model.predict(new_image, conf=0.2)
# Out:
# image 1/1 /content/Teknofest-Quantum-2025-1/test/images/15_png.rf.e30c52c9fa7ca06defb680486433f313.jpg: 640x640 9 alandisis, 3 dostuss, 2 dusmanuss, 23 engels, 6 yols, 19.9ms
# Speed: 5.4ms preprocess, 19.9ms inference, 16.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
new_result_array = new_results[0].plot()
plt.figure(figsize=(12, 12))
plt.imshow(new_result_array)

# %%
new_image2 = '/content/Teknofest-Quantum-2025-1/test/images/32_png.rf.2d1a1bb7e2d6b0d7f083ed8bf001419c.jpg'
new_results2 = my_new_model.predict(new_image2, conf=0.2)
# Out:
# image 1/1 /content/Teknofest-Quantum-2025-1/test/images/32_png.rf.2d1a1bb7e2d6b0d7f083ed8bf001419c.jpg: 640x640 2 alandisis, 1 dostus, 10 engels, 3 yols, 11.9ms
# Speed: 2.7ms preprocess, 11.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
new_result_array = new_results2[0].plot()
plt.figure(figsize=(12, 12))
plt.imshow(new_result_array)

# %%
new_image2 = '/content/Teknofest-Quantum-2025-1/test/images/45_png.rf.c0a4b166a22e52878d4cb5704e1ec71a.jpg'
new_results2 = my_new_model.predict(new_image2, conf=0.2)
# Out:
# image 1/1 /content/Teknofest-Quantum-2025-1/test/images/45_png.rf.c0a4b166a22e52878d4cb5704e1ec71a.jpg: 640x640 6 alandisis, 1 dostus, 1 dusmanus, 12 engels, 4 yols, 12.7ms
# Speed: 3.2ms preprocess, 12.7ms inference, 3.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
new_result_array = new_results2[0].plot()
plt.figure(figsize=(12, 12))
plt.imshow(new_result_array)
