# %%
# Install the ultralytics package using pip
# !pip install ultralytics

# %%
from ultralytics import YOLO
from matplotlib import pyplot as plt
from PIL import Image

# %%
model = YOLO('yolov8n-seg.yaml')  # build a new model from YAML
model = YOLO('yolov8n-seg.pt')

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lT5dh03nVQTwMwa0lXtS")
project = rf.workspace("sevde-aslantrkiyeli").project("bitirme-odevi-2")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Bitirme-Ödevi-2-1 in yolov8:: 100%|██████████| 312/312 [00:00<00:00, 5459.85it/s]

# %%
project = "/content/Bitirme-Ödevi-2-1"
#Define subdirectory for this specific training
name = "200_epochs-"

# %%
results = model.train(data='/content/Bitirme-Ödevi-2-1/data.yaml',
                      project=project,
                      name=name,
                      epochs=200,
                      patience=0,
                      batch=4,
                      imgsz=640)
# Out:
# Ultralytics 8.3.109 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
my_new_model = YOLO('/content/Bitirme-Ödevi-2-1/200_epochs-/weights/best.pt')

# %%
new_image = '/content/Bitirme-Ödevi-2/test/Ekran-goruntusu-2025-04-13-005139_png.rf.5f2bd37a4c46498a2abaf8959dcb427d.jpg'
new_results = my_new_model.predict(new_image, conf=0.2)
# Out:
# image 1/1 /content/Bitirme-Ödevi-2/test/Ekran-goruntusu-2025-04-13-005139_png.rf.5f2bd37a4c46498a2abaf8959dcb427d.jpg: 640x640 3 others, 6 plants, 5 roads, 11.8ms
# Speed: 3.9ms preprocess, 11.8ms inference, 20.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
new_result_array = new_results[0].plot()
plt.figure(figsize=(12, 12))
plt.imshow(new_result_array)

# %%
new_image2 = '/content/Bitirme-Ödevi-2/test/Ekran-goruntusu-2025-04-13-010008_png.rf.3600f674fe2cb39419d611caa5a6c5c0.jpg'
new_results2 = my_new_model.predict(new_image2, conf=0.2)
# Out:
# image 1/1 /content/Bitirme-Ödevi-2/test/Ekran-goruntusu-2025-04-13-010008_png.rf.3600f674fe2cb39419d611caa5a6c5c0.jpg: 640x640 8 others, 13 plants, 2 roads, 9.4ms
# Speed: 2.0ms preprocess, 9.4ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
new_result_array = new_results2[0].plot()
plt.figure(figsize=(12, 12))
plt.imshow(new_result_array)

# %%
new_results[0]
# Out:
# ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: ultralytics.engine.results.Masks object
# names: {0: 'agac', 1: 'engel', 2: 'ev', 3: 'yol'}
# obb: None
# orig_img: array([[[254, 254, 254],
#         [255, 255, 255],
#         [252, 252, 252],
#         ...,
#         [253, 253, 253],
#         [253, 253, 253],
#         [254, 254, 254]],
#
#        [[248, 248, 248],
#         [250, 250, 250],
#         [249, 249, 249],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[243, 243, 243],
#         [246, 246, 246],
#         [246, 246, 246],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[246, 247, 245],
#         [247, 248, 246],
#         [250, 251, 249],
#         ...,
#         [254, 254, 254],
#         [255, 255, 255],
#         [255, 255, 255]],
#
# ...
